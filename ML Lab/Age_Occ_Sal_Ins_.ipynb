# %%
import numpy as np
import pandas as pd
age=np.random.randint(20,61,100)
occ=np.random.randint(0,4,100)
salary=np.random.randint(20000,100001,100)

# %%
ins=[]
for a,o,s in zip(age,occ,salary):
    if a>40 and o==0  and s>50000:
        ins.append('Yes')
    else:
        ins.append('No')

# %%
df = pd.DataFrame({
    'Age': age,
    'Occupation': occ,
    'Salary': salary,
    'Insurance': ins
})

# %%
df.head(10)
# Out:
#    Age  Occupation  Salary Insurance
# 0   37           1   93599        No
# 1   36           1   93990        No
# 2   47           1   40326        No
# 3   23           2   90242        No
# 4   35           3   49798        No
# 5   42           0   72361       Yes
# 6   32           0   45603        No
# 7   25           0   30451        No
# 8   41           3   78931        No
# 9   52           0   25272        No

# %%
x=df[['Age','Occupation','Salary']]
y=df['Insurance']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.4,random_state=10)
sc = StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
pred = model.predict(x_test)
acc = accuracy_score(y_test,pred)
print("Accuracy: ",acc)
# Out:
# Accuracy:  0.95

# %%
df1=pd.DataFrame({'Actual': y_test,'Predicted': pred})
df1
# Out:
#    Actual Predicted
# 19     No        No
# 14     No        No
# 43     No        No
# 37     No        No
# 66     No        No
# 3      No        No
# 79     No        No
# 41     No        No
# 38     No        No
# 68     No        No
# 2      No        No
# 1      No        No
# 60     No        No
# 53     No        No
# 95     No        No
# 74     No        No
# 92     No        No
# 26     No        No
# 59     No        No
# 46     No        No
# 90     No        No
# 70     No        No
# 50     No        No
# 44     No        No
# 76    Yes        No
# 55     No        No
# 21     No        No
# 61     No        No
# 6      No        No
# 63     No        No
# 42     No        No
# 34     No        No
# 84     No        No
# 52     No        No
# 35     No        No
# 39     No        No
# 45     No        No
# 4      No        No
# 5     Yes        No
# 48     No        No

# %%
input_data = {'Age': 42, 'Occupation': 0, 'Salary': 72361}
input_df = pd.DataFrame([input_data])

input_scaled = sc.transform(input_df)

prediction = model.predict(input_scaled)
print(f"Prediction: {'Yes' if prediction[0] == 1 else 'No'}")
# Out:
# Prediction: No
